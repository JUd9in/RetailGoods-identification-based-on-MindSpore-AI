# %%
# !wget https://blob-nips2020-rp2k-dataset.obs.cn-east-3.myhuaweicloud.com/rp2k_dataset.zip
# Out:
# --2021-11-22 01:24:33--  https://blob-nips2020-rp2k-dataset.obs.cn-east-3.myhuaweicloud.com/rp2k_dataset.zip
# Resolving proxy-notebook.modelarts-dev-proxy.com (proxy-notebook.modelarts-dev-proxy.com)... 192.168.0.172
# Connecting to proxy-notebook.modelarts-dev-proxy.com (proxy-notebook.modelarts-dev-proxy.com)|192.168.0.172|:8083... connected.
# Proxy request sent, awaiting response... 200 OK
# Length: 6330687649 (5.9G) [application/zip]
# Saving to: ‘rp2k_dataset.zip’
#
# rp2k_dataset.zip    100%[===================>]   5.90G  33.6MB/s    in 2m 49s
#
# 2021-11-22 01:27:23 (35.7 MB/s) - ‘rp2k_dataset.zip’ saved [6330687649/6330687649]

# %%
# !unzip rp2k_dataset.zip
# Out:
# Archive:  rp2k_dataset.zip
#    creating: all/test/
#    creating: all/test/清扬男士活力运动薄荷型洗发露205g/
#   inflating: all/test/清扬男士活力运动薄荷型洗发露205g/234252.jpg
#    creating: all/test/李锦记铁强化金标生抽/
#   inflating: all/test/李锦记铁强化金标生抽/0430_32995.jpg
#   inflating: all/test/李锦记铁强化金标生抽/0430_97232.jpg
#   inflating: all/test/李锦记铁强化金标生抽/0717_97912.jpg
#   inflating: all/test/李锦记铁强化金标生抽/0717_97924.jpg
#   inflating: all/test/李锦记铁强化金标生抽/0430_23486.jpg
#    creating: all/test/红双喜（南洋1905）/
#   inflating: all/test/红双喜（南洋1905）/屏幕快照 2020-02-16 下午6.14.28 2.png
#    creating: all/test/青岛啤酒足球罐330ml/
#   inflating: all/test/青岛啤酒足球罐330ml/0901_3814.jpg
#   inflating: all/test/青岛啤酒足球罐330ml/0901_1272.jpg
#   inflating: all/test/青岛啤酒足球罐330ml/0901_3815.jpg
#    creating: all/test/加加蒸鱼豉油/
#   inflating: all/test/加加蒸鱼豉油/1031_24957.jpg
#   inflating: all/test/加加蒸鱼豉油/1031_40492.jpg
#   inflating: all/test/加加蒸鱼豉油/1031_77542.jpg
#   inflating: all/test/加加蒸鱼豉油/1031_18689.jpg
#   inflating: all/test/加加蒸鱼豉油/1031_45474.jpg
#   inflating: all/test/加加蒸鱼豉油/575_1011.jpg
#    creating: all/test/建牌（薄荷紫冰1）/
#   inflating: all/test/建牌（薄荷紫冰1）/0205_1379.jpg
#   inflating: all/test/建牌（薄荷紫冰1）/截屏2019-12-12下午8.54.15.png
#    creating: all/test/王致和烹饪黄酒/
#   inflating: all/test/王致和烹饪黄酒/13312.jpg
#    creating: all/test/青岛啤酒经典11度330罐啤箱装/
#   inflating: all/test/青岛啤酒经典11度330罐啤箱装/7868_0819_qiyun.jpg
#   inflating: all/test/青岛啤酒经典11度330罐啤箱装/1009_19766.jpg
#   inflating: all/test/青岛啤酒经典11度330罐啤箱装/1009_56131.jpg
#   inflating: all/test/青岛啤酒经典11度330罐啤箱装/928_14248.jpg
#   inflating: all/test/青岛啤酒经典11度330罐啤箱装/0518_8067_0.5135586.jpg
#   inflating: all/test/海天金标生抽500ML/0514_51031_1.0.jpg
#   inflating: all/test/海天金标生抽500ML/0717_24958.jpg
#   inflating: all/test/海天金标生抽500ML/0514_18423_0.99942076.jpg

# %%
# easydict模块用于以属性的方式访问字典的值
from easydict import EasyDict as edict
# os模块主要用于处理文件和目录
import os

import numpy as np
import matplotlib.pyplot as plt

import mindspore
# 导入mindspore框架数据集
import mindspore.dataset as ds
# vision.c_transforms模块是处理图像增强的高性能模块，用于数据增强图像数据改进训练模型。
from mindspore.dataset.vision import c_transforms as vision
from mindspore import context
import mindspore.nn as nn
from mindspore.train import Model
from mindspore.nn.optim.momentum import Momentum
from mindspore.train.callback import ModelCheckpoint, CheckpointConfig, LossMonitor
from mindspore import Tensor
from mindspore.train.serialization import export
from mindspore.train.loss_scale_manager import FixedLossScaleManager
from mindspore.train.serialization import load_checkpoint, load_param_into_net
import mindspore.ops as ops

# 设置MindSpore的执行模式和设备
context.set_context(mode=context.GRAPH_MODE, device_target="Ascend")
# from PIL import Image
# img=Image.open('all/train/555（金.锐）/jkl2.jpg')
# w,h=img.size
# print(w,h)

# %%
# import os
# import imghdr
# import tqdm
# from PIL import Image


# all_files = [i for i in os.listdir("all/train")]

# # 全部改为jpg格式,重命名
# for i in tqdm.tqdm(range(len(all_files))):
#     s = "all/train/" + all_files[i]
#     temp = os.listdir(s)
#     for j in range(len(temp)):
#         file_name = s + '/' + temp[j]
#         # if imghdr.what(file_name) != 'jpeg':  
#         os.rename(file_name, s + '/jkl' + str(j) + '.jpg')

# %%
cfg = edict({
    'data_path': 'all/train',  # 训练数据集，如果是zip文件需要解压
    'test_path': 'all/test',  # 测试数据集，如果是zip文件需要解压
    'data_size': 344736,#344832
    'HEIGHT': 220,  # 图片高度
    'WIDTH': 180,  # 图片宽度
    '_R_MEAN': 123.68,
    '_G_MEAN': 116.78,
    '_B_MEAN': 103.94,
    '_R_STD': 1,
    '_G_STD': 1,
    '_B_STD': 1,
    '_RESIZE_SIDE_MIN': 180,
    '_RESIZE_SIDE_MAX': 180,

    'batch_size': 128,
    'num_class': 2383,  # 分类类别
    'epoch_size': 30,  # 训练次数
    'loss_scale_num': 1024,

    'prefix': 'resnet-ai',
    'directory': './model_resnet',
    'save_checkpoint_steps': 10,
})

# %%
# 读取类别
def class_get():
    class_indexing = {}
    number = 0
    for root, dirs, files in os.walk("all/train"):
        if '\\' in root:
            class_indexing.update({root.split('\\')[1]: number})
            number += 1
    return class_indexing


# 数据处理
def read_data(path, config, usage="train"):
    # 从目录中读取图像的源数据集。
    dataset = ds.ImageFolderDataset(path,
                                    class_indexing=class_get())
    # define map operations
    decode_op = vision.Decode()
    normalize_op = vision.Normalize(mean=[cfg._R_MEAN, cfg._G_MEAN, cfg._B_MEAN],
                                    std=[cfg._R_STD, cfg._G_STD, cfg._B_STD])
    resize_op = vision.Resize(cfg._RESIZE_SIDE_MIN)
    center_crop_op = vision.CenterCrop((cfg.HEIGHT, cfg.WIDTH))
    horizontal_flip_op = vision.RandomHorizontalFlip()
    channelswap_op = vision.HWC2CHW()
    random_crop_decode_resize_op = vision.RandomCropDecodeResize((cfg.HEIGHT, cfg.WIDTH), (0.5, 1.0), (1.0, 1.0),
                                                                 max_attempts=100)

    if usage == 'train':
        dataset = dataset.map(input_columns="image", operations=random_crop_decode_resize_op)
        dataset = dataset.map(input_columns="image", operations=horizontal_flip_op)
    else:
        dataset = dataset.map(input_columns="image", operations=decode_op)
        dataset = dataset.map(input_columns="image", operations=resize_op)
        dataset = dataset.map(input_columns="image", operations=center_crop_op)

    dataset = dataset.map(input_columns="image", operations=normalize_op)
    dataset = dataset.map(input_columns="image", operations=channelswap_op)

    if usage == 'train':
        dataset = dataset.shuffle(buffer_size=100000)  # 400000 as in imageNet train script
        dataset = dataset.batch(cfg.batch_size, drop_remainder=True)
    else:
        dataset = dataset.batch(1, drop_remainder=True)
    dataset = dataset.repeat(1)
    dataset.map_model = 4

    return dataset


de_train = read_data(cfg.data_path, cfg, usage="train")
de_test = read_data(cfg.test_path, cfg, usage="test")
print('训练数据集数量：', de_train.get_dataset_size() * cfg.batch_size)  # get_dataset_size()获取批处理的大小。
print('测试数据集数量：', de_test.get_dataset_size())

de_dataset = de_train
data_next = de_dataset.create_dict_iterator(output_numpy=True).__next__()
print('通道数/图像长/宽：', data_next['image'][0, ...].shape)
print('一张图像的标签样式：', data_next['label'][0])  # 一共5类，用0-4的数字表达类别。

plt.figure()
plt.imshow(data_next['image'][0, 0, ...])
plt.colorbar()
plt.grid(False)
plt.show()
# Out:
# 训练数据集数量： 333312
# 测试数据集数量： 39458
# 通道数/图像长/宽： (3, 220, 180)
# 一张图像的标签样式： 1212

# %%
"""ResNet."""
def _weight_variable(shape, factor=0.01):
    init_value = np.random.randn(*shape).astype(np.float32) * factor
    return Tensor(init_value)


def _conv3x3(in_channel, out_channel, stride=1):
    weight_shape = (out_channel, in_channel, 3, 3)
    weight = _weight_variable(weight_shape)
    return nn.Conv2d(in_channel, out_channel,
                     kernel_size=3, stride=stride, padding=0, pad_mode='same', weight_init=weight)


def _conv1x1(in_channel, out_channel, stride=1):
    weight_shape = (out_channel, in_channel, 1, 1)
    weight = _weight_variable(weight_shape)
    return nn.Conv2d(in_channel, out_channel,
                     kernel_size=1, stride=stride, padding=0, pad_mode='same', weight_init=weight)


def _conv7x7(in_channel, out_channel, stride=1):
    weight_shape = (out_channel, in_channel, 7, 7)
    weight = _weight_variable(weight_shape)
    return nn.Conv2d(in_channel, out_channel,
                     kernel_size=7, stride=stride, padding=0, pad_mode='same', weight_init=weight)


def _bn(channel):
    return nn.BatchNorm2d(channel, eps=1e-4, momentum=0.9,
                          gamma_init=1, beta_init=0, moving_mean_init=0, moving_var_init=1)


def _bn_last(channel):
    return nn.BatchNorm2d(channel, eps=1e-4, momentum=0.9,
                          gamma_init=0, beta_init=0, moving_mean_init=0, moving_var_init=1)


def _fc(in_channel, out_channel):
    weight_shape = (out_channel, in_channel)
    weight = _weight_variable(weight_shape)
    return nn.Dense(in_channel, out_channel, has_bias=True, weight_init=weight, bias_init=0)


class ResidualBlock(nn.Cell):
    """
    ResNet V1 residual block definition.

    Args:
        in_channel (int): Input channel.
        out_channel (int): Output channel.
        stride (int): Stride size for the first convolutional layer. Default: 1.

    Returns:
        Tensor, output tensor.

    Examples:
        >>> ResidualBlock(3, 256, stride=2)
    """
    expansion = 4

    def __init__(self,
                 in_channel,
                 out_channel,
                 stride=1):
        super(ResidualBlock, self).__init__()

        channel = out_channel // self.expansion
        self.conv1 = _conv1x1(in_channel, channel, stride=1)
        self.bn1 = _bn(channel)

        self.conv2 = _conv3x3(channel, channel, stride=stride)
        self.bn2 = _bn(channel)

        self.conv3 = _conv1x1(channel, out_channel, stride=1)
        self.bn3 = _bn_last(out_channel)

        self.relu = nn.ReLU()

        self.down_sample = False

        if stride != 1 or in_channel != out_channel:
            self.down_sample = True
        self.down_sample_layer = None

        if self.down_sample:
            self.down_sample_layer = nn.SequentialCell([_conv1x1(in_channel, out_channel, stride),
                                                        _bn(out_channel)])
        self.add = ops.Add()

    def construct(self, x): # pylint: disable=missing-docstring
        identity = x

        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)

        out = self.conv2(out)
        out = self.bn2(out)
        out = self.relu(out)

        out = self.conv3(out)
        out = self.bn3(out)

        if self.down_sample:
            identity = self.down_sample_layer(identity)

        out = self.add(out, identity)
        out = self.relu(out)

        return out


class ResNet(nn.Cell):
    """
    ResNet architecture.

    Args:
        block (Cell): Block for network.
        layer_nums (list): Numbers of block in different layers.
        in_channels (list): Input channel in each layer.
        out_channels (list): Output channel in each layer.
        strides (list):  Stride size in each layer.
        num_classes (int): The number of classes that the training images are belonging to.
    Returns:
        Tensor, output tensor.

    Examples:
        >>> ResNet(ResidualBlock,
        >>>        [3, 4, 6, 3],
        >>>        [64, 256, 512, 1024],
        >>>        [256, 512, 1024, 2048],
        >>>        [1, 2, 2, 2],
        >>>        10)
    """

    def __init__(self,
                 block,
                 layer_nums,
                 in_channels,
                 out_channels,
                 strides,
                 num_classes):
        super(ResNet, self).__init__()

        if not len(layer_nums) == len(in_channels) == len(out_channels) == 4:
            raise ValueError("the length of layer_num, in_channels, out_channels list must be 4!")

        self.conv1 = _conv7x7(3, 64, stride=2)
        self.bn1 = _bn(64)
        self.relu = ops.ReLU()
        self.maxpool = nn.MaxPool2d(kernel_size=3, stride=2, pad_mode="same")

        self.layer1 = self._make_layer(block,
                                       layer_nums[0],
                                       in_channel=in_channels[0],
                                       out_channel=out_channels[0],
                                       stride=strides[0])
        self.layer2 = self._make_layer(block,
                                       layer_nums[1],
                                       in_channel=in_channels[1],
                                       out_channel=out_channels[1],
                                       stride=strides[1])
        self.layer3 = self._make_layer(block,
                                       layer_nums[2],
                                       in_channel=in_channels[2],
                                       out_channel=out_channels[2],
                                       stride=strides[2])
        self.layer4 = self._make_layer(block,
                                       layer_nums[3],
                                       in_channel=in_channels[3],
                                       out_channel=out_channels[3],
                                       stride=strides[3])

        self.mean = ops.ReduceMean(keep_dims=True)
        self.flatten = nn.Flatten()
        self.end_point = _fc(out_channels[3], num_classes)

    def _make_layer(self, block, layer_num, in_channel, out_channel, stride):
        """
        Make stage network of ResNet.

        Args:
            block (Cell): Resnet block.
            layer_num (int): Layer number.
            in_channel (int): Input channel.
            out_channel (int): Output channel.
            stride (int): Stride size for the first convolutional layer.

        Returns:
            SequentialCell, the output layer.

        Examples:
            >>> _make_layer(ResidualBlock, 3, 128, 256, 2)
        """
        layers = []

        resnet_block = block(in_channel, out_channel, stride=stride)
        layers.append(resnet_block)

        for _ in range(1, layer_num):
            resnet_block = block(out_channel, out_channel, stride=1)
            layers.append(resnet_block)

        return nn.SequentialCell(layers)

    def construct(self, x): # pylint: disable=missing-docstring
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        c1 = self.maxpool(x)

        c2 = self.layer1(c1)
        c3 = self.layer2(c2)
        c4 = self.layer3(c3)
        c5 = self.layer4(c4)

        out = self.mean(c5, (2, 3))
        out = self.flatten(out)
        out = self.end_point(out)

        return out


def resnet50(class_num=10):
    """
    Get ResNet50 neural network.

    Args:
        class_num (int): Class number.

    Returns:
        Cell, cell instance of ResNet50 neural network.

    Examples:
        >>> net = resnet50(10)
    """
    return ResNet(ResidualBlock,
                  [3, 4, 6, 3],
                  [64, 256, 512, 1024],
                  [256, 512, 1024, 2048],
                  [1, 2, 2, 2],
                  class_num)


def resnet101(class_num=1001):
    """
    Get ResNet101 neural network.

    Args:
        class_num (int): Class number.

    Returns:
        Cell, cell instance of ResNet101 neural network.

    Examples:
        >>> net = resnet101(1001)
    """
    return ResNet(ResidualBlock,
                  [3, 4, 23, 3],
                  [64, 256, 512, 1024],
                  [256, 512, 1024, 2048],
                  [1, 2, 2, 2],
                  class_num)


def get_lr(global_step,
           total_epochs,
           steps_per_epoch,
           lr_init=0.01,
           lr_max=0.1,
           warmup_epochs=5):
    """
    Generate learning rate array.

    Args:
        global_step (int): Initial step of training.
        total_epochs (int): Total epoch of training.
        steps_per_epoch (float): Steps of one epoch.
        lr_init (float): Initial learning rate. Default: 0.01.
        lr_max (float): Maximum learning rate. Default: 0.1.
        warmup_epochs (int): The number of warming up epochs. Default: 5.

    Returns:
        np.array, learning rate array.
    """
    lr_each_step = []
    total_steps = steps_per_epoch * total_epochs
    warmup_steps = steps_per_epoch * warmup_epochs
    if warmup_steps != 0:
        inc_each_step = (float(lr_max) - float(lr_init)) / float(warmup_steps)
    else:
        inc_each_step = 0
    for i in range(int(total_steps)):
        if i < warmup_steps:
            lr = float(lr_init) + inc_each_step * float(i)
        else:
            base = ( 1.0 - (float(i) - float(warmup_steps)) / (float(total_steps) - float(warmup_steps)) )
            lr = float(lr_max) * base * base
            if lr < 0.0:
                lr = 0.0
        lr_each_step.append(lr)

    current_step = global_step
    lr_each_step = np.array(lr_each_step).astype(np.float32)
    learning_rate = lr_each_step[current_step:]

    return learning_rate

# %%
net=resnet50(class_num=cfg.num_class)
#计算softmax交叉熵。
loss = nn.SoftmaxCrossEntropyWithLogits(sparse=True, reduction="mean")
#设置Adam优化器
train_step_size = de_train.get_dataset_size()
lr = Tensor(get_lr(global_step=0, total_epochs=cfg.epoch_size, steps_per_epoch=train_step_size))
opt = Momentum(net.trainable_params(), lr, momentum=0.9, weight_decay=1e-4, loss_scale=cfg.loss_scale_num)
#opt = Momentum(filter(lambda x: x.requires_grad, net.get_parameters()), 0.002,
#                       0.9, 0.00004, loss_scale=1024.0)
loss_scale = FixedLossScaleManager(cfg.loss_scale_num, False)

model = Model(net, loss_fn=loss, optimizer=opt, loss_scale_manager=loss_scale, metrics={'acc'})
loss_cb = LossMonitor(per_print_times=train_step_size)
ckpt_config = CheckpointConfig(save_checkpoint_steps=cfg.save_checkpoint_steps, keep_checkpoint_max=1)
ckpoint_cb = ModelCheckpoint(prefix=cfg.prefix, directory=cfg.directory, config=ckpt_config)

print("============== Starting Training ==============")
model.train(cfg.epoch_size, de_train, callbacks=[loss_cb,ckpoint_cb], dataset_sink_mode=True)
# Out:
# ============== Starting Training ==============
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/miniconda3/envs/MindSpore-python3.7-aarch64/lib/python3.7/site-packages/mindspore/train/model.py in _train(self, epoch, train_dataset, callbacks, dataset_sink_mode, sink_size)
#     438             else:
# --> 439                 self._train_dataset_sink_process(epoch, train_dataset, list_callback, cb_params, sink_size)
#     440
#
# ~/miniconda3/envs/MindSpore-python3.7-aarch64/lib/python3.7/site-packages/mindspore/train/model.py in _train_dataset_sink_process(self, epoch, train_dataset, list_callback, cb_params, sink_size)
#     489                                                                   epoch_num=epoch_num,
# --> 490                                                                   dataset_helper=dataset_helper)
#     491
#
# ~/miniconda3/envs/MindSpore-python3.7-aarch64/lib/python3.7/site-packages/mindspore/train/model.py in _exec_preprocess(self, is_train, dataset, dataset_sink_mode, sink_size, epoch_num, dataset_helper)
#     321         if dataset_helper is None:
# --> 322             dataset_helper = DatasetHelper(dataset, dataset_sink_mode, sink_size, epoch_num)
#     323
#
# ~/miniconda3/envs/MindSpore-python3.7-aarch64/lib/python3.7/site-packages/mindspore/train/dataset_helper.py in __init__(self, dataset, dataset_sink_mode, sink_size, epoch_num)
#     244                     iterclass = _DatasetIterPyNative
# --> 245             self.iter = iterclass(dataset, sink_size, epoch_num)
#     246         else:
#
# ~/miniconda3/envs/MindSpore-python3.7-aarch64/lib/python3.7/site-packages/mindspore/train/dataset_helper.py in __init__(self, dataset, sink_size, epoch_num)
#     391     def __init__(self, dataset, sink_size, epoch_num):
# --> 392         super().__init__(dataset, sink_size, epoch_num)
#     393         self.sink_count = self.get_sink_count(dataset)
#
# ~/miniconda3/envs/MindSpore-python3.7-aarch64/lib/python3.7/site-packages/mindspore/train/dataset_helper.py in __init__(self, dataset, sink_size, epoch_num)
#     298             dataset.__transfer_dataset__ = _exec_datagraph(dataset, self.sink_size,
# --> 299                                                            create_data_info_queue=create_data_info_queue)
#     300
#
# ~/miniconda3/envs/MindSpore-python3.7-aarch64/lib/python3.7/site-packages/mindspore/train/_utils.py in _exec_datagraph(exec_dataset, dataset_size, phase, create_data_info_queue)
#      72                            input_indexs,
# ---> 73                            phase=phase)
#      74
#
# ~/miniconda3/envs/MindSpore-python3.7-aarch64/lib/python3.7/site-packages/mindspore/common/api.py in init_dataset(self, queue_name, dataset_size, batch_size, dataset_types, dataset_shapes, input_indexs, phase)
#     472                                  input_indexs=input_indexs,
# --> 473                                  phase=phase):
#     474             raise RuntimeError("Failure to init and dataset subgraph!")
#
# RuntimeError: mindspore/ccsrc/backend/session/kernel_build_client.h:176 GetScriptFilePath] py file seems incorrect, result: {}
#
# #
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-cdf31e65e22d> in <module>
#      16
#      17 print("============== Starting Training ==============")
# ---> 18 model.train(cfg.epoch_size, de_train, callbacks=[loss_cb,ckpoint_cb], dataset_sink_mode=True)
#
# ~/miniconda3/envs/MindSpore-python3.7-aarch64/lib/python3.7/site-packages/mindspore/train/model.py in train(self, epoch, train_dataset, callbacks, dataset_sink_mode, sink_size)
#     647                     callbacks=callbacks,
#     648                     dataset_sink_mode=dataset_sink_mode,
# --> 649                     sink_size=sink_size)
#     650
#     651     def _eval_dataset_sink_process(self, valid_dataset, list_callback=None, cb_params=None):
#
# ~/miniconda3/envs/MindSpore-python3.7-aarch64/lib/python3.7/site-packages/mindspore/train/model.py in _train(self, epoch, train_dataset, callbacks, dataset_sink_mode, sink_size)
#     437                 self._train_process(epoch, train_dataset, list_callback, cb_params)
#     438             else:
# --> 439                 self._train_dataset_sink_process(epoch, train_dataset, list_callback, cb_params, sink_size)
#     440
#     441     @staticmethod
#
# KeyboardInterrupt:

# %%
model=model_resnet2/resnet-ai-14_2604.ckpt
metric = model.eval(de_test)
print(metric)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-d589c90aa699> in <module>
# ----> 1 metric = model.eval(de_test)
#       2 print(metric)
#
# ~/miniconda3/envs/MindSpore-python3.7-aarch64/lib/python3.7/site-packages/mindspore/train/model.py in eval(self, valid_dataset, callbacks, dataset_sink_mode)
#     777         with _CallbackManager(callbacks) as list_callback:
#     778             if dataset_sink_mode:
# --> 779                 return self._eval_dataset_sink_process(valid_dataset, list_callback, cb_params)
#     780             return self._eval_process(valid_dataset, list_callback, cb_params)
#     781
#
# ~/miniconda3/envs/MindSpore-python3.7-aarch64/lib/python3.7/site-packages/mindspore/train/model.py in _eval_dataset_sink_process(self, valid_dataset, list_callback, cb_params)
#     674             list_callback.step_begin(run_context)
#     675
# --> 676             outputs = self._eval_network(*inputs)
#     677
#     678             cb_params.net_outputs = outputs
#
# ~/miniconda3/envs/MindSpore-python3.7-aarch64/lib/python3.7/site-packages/mindspore/nn/cell.py in __call__(self, *inputs, **kwargs)
#     384             if self.enable_hook:
#     385                 raise ValueError("The graph mode does not support hook function.")
# --> 386             out = self.compile_and_run(*inputs)
#     387             return out
#     388
#
# ~/miniconda3/envs/MindSpore-python3.7-aarch64/lib/python3.7/site-packages/mindspore/nn/cell.py in compile_and_run(self, *inputs)
#     658                 parallel_inputs_run = new_inputs
#     659             return _executor(self, *parallel_inputs_run, phase=self.phase)
# --> 660         return _executor(self, *new_inputs, phase=self.phase)
#     661
#     662     def auto_parallel_compile_and_run(self):
#
# ~/miniconda3/envs/MindSpore-python3.7-aarch64/lib/python3.7/site-packages/mindspore/common/api.py in __call__(self, obj, phase, *args)
#     609         if context.get_context("precompile_only") or _is_role_pserver():
#     610             return None
# --> 611         return self.run(obj, *args, phase=phase)
#     612
#     613     @_wrap_func
#
# ~/miniconda3/envs/MindSpore-python3.7-aarch64/lib/python3.7/site-packages/mindspore/common/api.py in run(self, obj, phase, *args)
#     637         phase_real = obj.phase_prefix + phase + '.' + str(obj.create_time) + '.' + str(id(obj))
#     638         if self.has_compiled(phase_real):
# --> 639             return self._exec_pip(obj, *args, phase=phase_real)
#     640         raise KeyError('{} graph is not exist.'.format(phase_real))
#     641
#
# ~/miniconda3/envs/MindSpore-python3.7-aarch64/lib/python3.7/site-packages/mindspore/common/api.py in wrapper(*arg, **kwargs)
#      73     @wraps(fn)
#      74     def wrapper(*arg, **kwargs):
# ---> 75         results = fn(*arg, **kwargs)
#      76
#      77         def _convert_data(data):
#
# ~/miniconda3/envs/MindSpore-python3.7-aarch64/lib/python3.7/site-packages/mindspore/common/api.py in _exec_pip(self, obj, phase, *args)
#     620         args_list = tuple(arguments_dict.values())
#     621         obj.__parse_method__ = parse_method
# --> 622         return self._executor(args_list, phase)
#     623
#     624     def run(self, obj, *args, phase='predict'):
#
# RuntimeError: mindspore/ccsrc/backend/session/ascend_session.cc:1137 Execute] run task error!
#
# # In file /home/ma-user/miniconda3/envs/MindSpore-python3.7-aarch64/lib/python3.7/site-packages/mindspore/nn/layer/conv.py(261)
#         output = self.conv2d(x, self.weight)
#              ^

# %%
#创建文件夹
if not os.path.exists('./rp2ks/'):
    os.mkdir('./rp2ks/')
param_dict = load_checkpoint(os.path.join(cfg.directory,cfg.prefix+'-'+str(cfg.epoch_size)+'_'+str(train_step_size)+'.ckpt'))

# load the parameter into net
resnet=resnet50(class_num=cfg.num_class)
load_param_into_net(resnet, param_dict)
x = np.random.uniform(-1.0, 1.0, size = [1, 3, cfg.HEIGHT, cfg.WIDTH]).astype(np.float32)   
export(resnet, Tensor(x), file_name = './rp2ks/best_model.onnx', file_format = 'ONNX')

# %%
#创建桶，根据自己情况修改路径
import moxing
moxing.file.copy_parallel(src_url='model_resnet2/resnet-ai-14_2604.ckpt', dst_url='obs://rp2kmm/rp2ks/ckpt/best_model.ckpt')
# Out:
# INFO:root:Using MoXing-v2.0.0.rc2.4b57a67b-4b57a67b
# INFO:root:Using OBS-Python-SDK-3.20.9.1
